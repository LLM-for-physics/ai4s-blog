# %%
import numpy as np

# %%
s = np.array([[1,2], [3,4]])
p = []
p.append(np.reshape(s, (4, 1)))
s[0][0] = 100
p.append(np.reshape(s, (4, 1)))

# %%
p
# Out:
# [array([[100],
#         [  2],
#         [  3],
#         [  4]]),
#  array([[100],
#         [  2],
#         [  3],
#         [  4]])]
